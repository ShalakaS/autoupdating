# %%
import requests
import re
import pandas as pd
from datetime import datetime
import pdfplumber
import certifi
import sys
import folium
from folium.plugins import HeatMap
import googlemaps
import pytz
from dotenv import load_dotenv
import os
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
# load_dotenv(override=False)
# API_KEY = os.getenv("GOOGLE_API_KEY")
# print("API_KEY loaded:", API_KEY is not None)
# print("API_KEY length:", len(API_KEY) if API_KEY else 0)

# %%
time_zone = pytz.timezone('Asia/Kolkata')
date = datetime.now(time_zone).strftime("%Y%m%d")
date
# Out:
# '20260715'

# %%
# date = '20260714'

# %%
time = datetime.now(time_zone).strftime("%H:%M:%S")

# %%
url = f'https://cpcb.gov.in//upload/Downloads/AQI_Bulletin_{date}.pdf'

# %%
response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"}, verify=True)

if response.status_code == 200:
    with open(f"AQI_Bulletin_{date}.pdf", "wb") as f:
        f.write(response.content)
    print("Download successful.")
else:
    print("Failed to download:", response.status_code)
# Out:
# Download successful.

# %%
daily_doc = f'AQI_Bulletin_{date}.pdf'

# %%
if daily_doc:
    tables = []
    with pdfplumber.open(daily_doc) as pdf:
        for page in pdf.pages[:-1]:
            extracted_tables = page.extract_tables()
            # print(extracted_tables[0])
            tables.extend(extracted_tables)

# %%
clean_tables = []
for table in tables:
    table_wihtout_headers = table[1:]
    clean_tables.append(table_wihtout_headers)

# %%
df_list = []
for each_table in clean_tables:
    df = pd.DataFrame(each_table)
    df_list.append(df)

# %%
df_combined = pd.concat(df_list, ignore_index=True)
df_combined.columns = tables[0][0]

# %%
df = df_combined.drop(columns=['S.No']) #, 'Prominent Pollutant', 'No. of Stations\nParticipated/\nTotal Stations'])

# %%
df.columns = df.columns.str.replace("\n", " ").str.replace(" ","_").str.replace("/", "")

# %%
df.columns
# Out:
# Index(['City', 'Air_Quality', 'Index_Value', 'Prominent_Pollutant',
#        'No._of_Stations_Participated_Total_Stations'],
#       dtype='object')

# %%
df['Index_Value'] = df['Index_Value'].astype(int)

# %%
# API_KEY = os.getenv("GOOGLE_API_KEY")

# %%
# print("API Key loaded:", API_KEY is not None)
# Out:
# API Key loaded: False

# %%
# import sys
# !{sys.executable} -m pip install geopy

# %%
import requests

CITY_CACHE = {}  # runtime cache to avoid repeat calls within same session

def geocode_google(city):
    city_key = city.replace(", India", "").strip()
    if city_key in CITY_CACHE:
        return pd.Series(CITY_CACHE[city_key][:2])
    try:
        r = requests.get(
            "https://geocoding-api.open-meteo.com/v1/search",
            params={"name": city_key, "count": 5, "language": "en", "format": "json"},
            timeout=10
        )
        results = r.json().get("results", [])
        # Filter to India results only
        india_results = [x for x in results if x.get("country_code") == "IN"]
        if india_results:
            best = india_results[0]
            lat, lng = best["latitude"], best["longitude"]
            state = best.get("admin1", None)  # admin1 = state in India
            CITY_CACHE[city_key] = (lat, lng, state)
            return pd.Series([lat, lng])
        return pd.Series([None, None])
    except Exception as e:
        print(f"[error] geocode failed for {city_key}: {e}")
        return pd.Series([None, None])

def get_state(city):
    city_key = city.replace(", India", "").strip()
    if city_key in CITY_CACHE:
        return CITY_CACHE[city_key][2]
    geocode_google(city)  # populates cache as a side effect
    return CITY_CACHE.get(city_key, (None, None, None))[2]

# %%
# gmaps = googlemaps.Client(key=API_KEY)

# %%
def get_state(city):
    city_key = city.replace(", India", "").strip()
    if city_key in CITY_CACHE:
        return CITY_CACHE[city_key][2]
    geocode_google(city_key)  # populates cache as a side effect
    return CITY_CACHE.get(city_key, (None, None, None))[2]

df["State"] = df["City"].apply(get_state)
# Out:
# [error] geocode failed for Ambala: HTTPSConnectionPool(host='geocoding-api.open-meteo.com', port=443): Read timed out. (read timeout=10)

# %%
# # Function to get state using reverse geocoding
# def get_state(city):
#     try:
#         geocode_result = gmaps.geocode(f"{city}, India")
#         for component in geocode_result[0]['address_components']:
#             if 'administrative_area_level_1' in component['types']:
#                 return component['long_name']
#     except Exception as e:
#         return None

# df["State"] = df["City"].apply(get_state)

# %%
df.sort_values(by='Index_Value', ascending=False).to_csv(f'daily_aqi_{date}.csv', index=False)

# %%
# # Function to geocode addresses
# def geocode_google(address):
#     try:
#         geocode_result = gmaps.geocode(address)
#         if geocode_result:
#             location = geocode_result[0]['geometry']['location']
#             return pd.Series([location['lat'], location['lng']])
#         else:
#             return pd.Series([None, None])
#     except Exception as e:
#         return pd.Series([None, None])

# %%
def geocode_google(address):
    city_key = address.replace(", India", "").strip()
    if city_key in CITY_CACHE:
        return pd.Series(CITY_CACHE[city_key][:2])
    try:
        r = requests.get(
            "https://geocoding-api.open-meteo.com/v1/search",
            params={"name": city_key, "count": 5, "language": "en", "format": "json"},
            timeout=10
        )
        results = r.json().get("results", [])
        india_results = [x for x in results if x.get("country_code") == "IN"]
        if india_results:
            best = india_results[0]
            lat, lng = best["latitude"], best["longitude"]
            state = best.get("admin1", None)
            CITY_CACHE[city_key] = (lat, lng, state)
            return pd.Series([lat, lng])
        return pd.Series([None, None])
    except Exception as e:
        print(f"[error] geocode failed for {city_key}: {e}")
        return pd.Series([None, None])

# %%
# Apply geocoding function to the DataFrame
df[['Latitude', 'Longitude']] = df['City'].apply(geocode_google)

# %%
df['date'] = date

# %%
if len(df[df['Latitude'].isna()]['City']) > 0:
    df[['Latitude', 'Longitude']] = df['City'].apply(geocode_google)

# %%
len(df[df['Latitude'].isna()]['City'])
# Out:
# 16

# %%
if len(df[df['Latitude'].isna()]['City']) > 0:
    df['Latitude'] = df['Latitude'].fillna('0')
    df['Longitude'] = df['Longitude'].fillna('0')

# %%
len(df[df['Latitude'].isna()]['City'])
# Out:
# 0

# %%
with pdfplumber.open(daily_doc) as pdf:
    last_page_text = pdf.pages[-1].extract_text()

# %%
text = last_page_text.replace("\n", " ")

# %%
list_of_no_data_cities = text.split(":")[1].split(",")

# %%
no_data_cities = []
for each_city in list_of_no_data_cities:
    city_name = each_city.split(")")[1].strip()
    no_data_cities.append(city_name)

# %%
geocoded_no_data_cities = []
for each_city in no_data_cities:
    no_data_city_dict = {}
    no_data_city_dict['city'] = each_city 
    no_data_city_dict['lat'] = geocode_google(each_city)[0]
    no_data_city_dict['long'] = geocode_google(each_city)[1]
    geocoded_no_data_cities.append(no_data_city_dict)

# %%
df_no_data = pd.DataFrame(geocoded_no_data_cities)
df_no_data['state'] = df_no_data['city'].apply(get_state)

# %%
df_no_data['date'] = date

# %%
if len(df_no_data[df_no_data['lat'].isna()]) > 0:
    df_no_data['city'].apply(geocode_google)

# %%
if len(df_no_data[df_no_data['lat'].isna()]) > 0:
    df_no_data['lat'] = df_no_data['lat'].fillna('0')
    df_no_data['long'] = df_no_data['long'].fillna('0')

# %%
df_no_data.to_csv('no_data_cities.csv', index=False)

# %%
# Create base map
m1 = folium.Map(location=[22.9734, 78.6569], zoom_start=4.5)

map_date = pd.to_datetime(df['date'].iloc[0]).strftime("%B %d, %Y")  # Optional formatting

# Define map center
map_center = [33.9734, 78.6569]

heat_data = [[row['Latitude'], row['Longitude'], row['Index_Value']] for index, row in df.iterrows()]
HeatMap(heat_data, radius=13, blur=10, max_zoom=4.5).add_to(m1)

folium.map.Marker(
    [33.5, 78],  # Approximate location to place annotation (adjust as needed)
    icon=folium.DivIcon(html="""
        <div style="position: absolute; top: 10px; left: 10px; font-size: 12px; font-weight: bold; 
                    background: rgba(255, 255, 255, 0.5); padding: 2px; border-radius: 1px; 
                    border: 1px solid; white-space: nowrap; z-index:9999;">
            Zoom in at area of interest
        </div>
    """)
).add_to(m1)

folium.map.Marker(
    map_center,
    icon=folium.DivIcon(html=f"""
        <div style="text-align: center; font-size: 12px; min-width: 120px; font-weight: bold; 
                    background: rgba(255, 255, 255, 0.3); padding: 0px 0px; border-radius: 1px; 
                    border: 1px solid; z-index:9999;">
            {map_date}
        </div>
    """)
).add_to(m1)

m1.save(f"daily_map_{date}.html")

# %%
with open(f"daily_map_{date}.html", "r") as source_file:
    content = source_file.read()

with open("daily_map.html", "w") as target_file:
    target_file.write(content)

# %%
# Create a base map centered around India
m2 = folium.Map(location=[22.9734, 78.9629], zoom_start=4.5)

# Add markers with city names as labels
for _, row in df_no_data.iterrows():
    folium.Marker(
        location=[row["lat"], row["long"]],
        popup=folium.Popup(row["city"], parse_html=True),
        icon=folium.Icon(color="red", icon="flag")
    ).add_to(m2)

folium.map.Marker(
    [33.5, 78],  # Approximate location to place annotation (adjust as needed)
    icon=folium.DivIcon(html="""
        <div style="position: absolute; top: 10px; left: 10px; font-size: 12px; font-weight: bold; 
                    background: rgba(255, 255, 255, 0.5); padding: 2px; border-radius: 1px; 
                    border: 1px solid; white-space: nowrap; z-index:9999;">
            Zoom in at area of interest
        </div>
    """)
).add_to(m2)

folium.map.Marker(
    map_center,
    icon=folium.DivIcon(html=f"""
        <div style="text-align: center; font-size: 12px; min-width: 120px; font-weight: bold; 
                    background: rgba(255, 255, 255, 0.3); padding: 0px 0px; border-radius: 1px; 
                    border: 1px solid; z-index:9999;">
            {map_date}
        </div>
    """)
).add_to(m2)

# Display the map
m2.save(f"no_data_map_{date}.html")

# %%
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
with open(f"no_data_map_{date}.html", "r") as source_file:
    content = source_file.read()

with open("no_data_map.html", "w") as target_file:
    target_file.write(content)

# %% [markdown]
# #Make an empty list
# #Save it to a csv
# #Read into the csv as df
# #Start adding to the df daily
# #Save it as csv again?
#
# OR
#
# #Once df is processed, change the name to have that day's date {date}
# #Sort descending and take head(10)
# #save in a different folder
# #Use os to read ontp the folder and make a list of files inside
# #Give it a condition: if len(list) > 7, then throw out the oldest one or wait for the new ones to collect into set of 7
# #Take mean and display in a table
