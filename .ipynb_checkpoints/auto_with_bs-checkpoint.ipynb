# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://ews.tropmet.res.in/'

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!--        <meta http-equiv='cache-control' content='no-cache'>
#         <meta http-equiv='expires' content='0'>
#         <meta http-equiv='pragma' content='no-cache'>-->
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Air Quality Early Warning System For Delhi</title>
# <link href="images/favicon.png" rel="icon" type="image/png"/>
# <link href="1/thumbs2.css" rel="stylesheet">
# <link href="https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/themes/base/jquery-ui.css" rel="stylesheet"/>
# <link href="https://netdna.bootstrapcdn.com/font-awesome/4.0.3/css/font-awesome.css" rel="stylesheet"/>
# <link href="assets/css/bootstrap2.min.css" rel="stylesheet"/>
# <link href="https://code.ionicframework.com/ionicons/2.0.1/css/ionicons.min.css" rel="stylesheet"/>
# ...

# %%
divs = soup.select("div.slideshow-container")
divs
# Out:
# [<div class="slideshow-container">
#  <div class="mySlidesclock">
#  <div class="row">
#  <div class="col-10 col-sm-10 col-md-10 pr-0">
#  <div class="bullet" style="font-family:Roboto Slab;font-size:18px; text-align: center; padding-top: 10px; padding-left: 30px">Air Quality Index at Delhi</div>
#  </div>
#  <div class="col-2 col-sm-2 col-md-2">
#  <div style="background-color:white;height:30px"><a class="trigger_popup_fricc">
#  <img height="30px" src="images/Info-logo2.jpg" style="float:right;background-color:transparent;" width="30px"/>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-12 col-sm-12 col-md-12">
#  <div align="center" class="chart" id="containers2"></div>
#  <div align="center" class="chart" id="containers1"></div>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-6 col-sm-6 col-md-6">
#  <div align="center" class="text-center ml-4" id="aqi_heading" style="font-family:Roboto Slab;">Current AQI </div>
#  </div>
# ...

# %%
for div in divs:
    print(div.text)
# Out:
# Air Quality Index at Delhi
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Current AQI
#
#
# Forecast
#
#
#
#
#
#
# Air Quality Index at Pune
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Current AQI
#
#
# Forecast
#
#
#
#
#
#
# Air Quality Index at Mumbai
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Current AQI
#
#
# Forecast
#
#
#
#
#
#
# Air Quality Index at Kolkata
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Current AQI
#
#
# Forecast
#
#
#
#
#
#
# Air Quality Index at Bengaluru
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Current AQI
#
#
# Forecast
#
#
#
#
#
#
# Air Quality Index at Lucknow
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Current AQI
#
#
# Forecast
#
#
#
#
#
#
# Air Quality Index at Patna
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Current AQI
#
#
# Forecast
#
#
#
#
#
#
# Air Quality Index at Hyderabad
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Current AQI
#
#
# Forecast
#
#
#
#
#
#
# Air Quality Index at Ahmedabad
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Current AQI
#
#
# Forecast
#
#
#
# ❮
# ❯

# %%
soup.select("div.mySlidesclock")
# Out:
# [<div class="mySlidesclock">
#  <div class="row">
#  <div class="col-10 col-sm-10 col-md-10 pr-0">
#  <div class="bullet" style="font-family:Roboto Slab;font-size:18px; text-align: center; padding-top: 10px; padding-left: 30px">Air Quality Index at Delhi</div>
#  </div>
#  <div class="col-2 col-sm-2 col-md-2">
#  <div style="background-color:white;height:30px"><a class="trigger_popup_fricc">
#  <img height="30px" src="images/Info-logo2.jpg" style="float:right;background-color:transparent;" width="30px"/>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-12 col-sm-12 col-md-12">
#  <div align="center" class="chart" id="containers2"></div>
#  <div align="center" class="chart" id="containers1"></div>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-6 col-sm-6 col-md-6">
#  <div align="center" class="text-center ml-4" id="aqi_heading" style="font-family:Roboto Slab;">Current AQI </div>
#  </div>
#  <div class="col-6 col-sm-6 col-md-6">
# ...

# %%
soup.select("div#containers2")
# Out:
# [<div align="center" class="chart" id="containers2"></div>]

# %%
soup.select("div#highcharts-gzz881c-7")
# Out:
# []
